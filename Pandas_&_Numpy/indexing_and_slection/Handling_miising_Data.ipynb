# %%
import pandas as pd 
import numpy as np 
from pathlib import Path

# %%
file_path = 'ramen-ratings.csv'
data = pd.read_csv(file_path)
data.head(10)
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
# 5      2575   Samyang Foods
# 6      2574         Acecook
# 7      2573     Ikeda Shoku
# 8      2572      Ripe'n'Dry
# 9      2571            KOKA
#
#                                              Variety Style      Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup        Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack       Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup          USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack       Taiwan  2.75
# 4                                    Singapore Curry  Pack        India  3.75
# 5                             Kimchi song Song Ramen  Pack  South Korea  4.75
# 6                Spice Deli Tantan Men With Cilantro   Cup        Japan     4
# ...

# %%
data.isnull().sum(axis = 0)  # sum None Values for every columns axis = 0 for clomuns   , axis = 1 for Rwa
# Out:
# Review #       0
# Brand          0
# Variety        0
# Style          2
# Country        0
# Stars          0
# Top Ten     2539
# dtype: int64

# %%
data.shape #  (rows, columns)    Top Ten columns have None rows values from 2580 DataFrame Rows
# Out:
# (2580, 7)

# %%
#   
(data.isnull().sum(axis = 0) / data.shape[0])*100  # Top Ten columns 99 % Non VAlue
# Out:
# Review #     0.000000
# Brand        0.000000
# Variety      0.000000
# Style        0.077519
# Country      0.000000
# Stars        0.000000
# Top Ten     98.410853
# dtype: float64

# %%
# Dropna  del all None Rows Value
df_na = data.copy()

df_na = df_na.dropna()
print(f'after drop.na value {df_na.shape} ---- befor del NaN values  # data.shape {data.shape}\n ---------------')  
print(df_na.isnull().sum(axis=0))
# Out:
# after drop.na value (41, 7) ---- befor del NaN values  # data.shape (2580, 7)
#  ---------------
# Review #    0
# Brand       0
# Variety     0
# Style       0
# Country     0
# Stars       0
# Top Ten     0
# dtype: int64

# %%
#drop the columns that contain nan 
df_na_columns = data.copy()
df_na_columns = df_na_columns.dropna(axis = 'columns')
print(f'after del cloumns have non value : {df_na_columns.shape}------befor del {data.shape}\n(rows,columns)')
print(f'columns name after {df_na_columns.columns.tolist()}\n ---------------------')
print(f'befor del columns : {data.columns.tolist()}')
# Out:
# after del cloumns have non value : (2580, 5)------befor del (2580, 7)
# (rows,columns)
# columns name after ['Review #', 'Brand', 'Variety', 'Country', 'Stars']
#  ---------------------
# befor del columns : ['Review #', 'Brand', 'Variety', 'Style', 'Country', 'Stars', 'Top Ten']

# %%
# change all Nan value to 0 
data_non_zero = data.copy()
data_non_zero = data_non_zero.fillna(0)
data_non_zero
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %%
#2. change non value 
df_new = data.fillna({'Style':'no style','Top Ten' : -1})
df_new
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %%
df_new.loc[df_new['Style']=='no style']
# Out:
#       Review #   Brand            Variety     Style Country Stars Top Ten
# 2152       428  Kamfen     E Menm Chicken  no style   China  3.75      -1
# 2442       138    Unif  100 Furong Shrimp  no style  Taiwan     3      -1
