# %%
import pandas as pd 
import numpy as np 
from pathlib import Path

# %%
files_path = Path('ramen-ratings.csv')
data = pd.read_csv(files_path)
data.head(5)
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# Let's have a look at the ramen dishes served in Taiwan 
data.loc[data['Country']=='Taiwan']
# Out:
#       Review #             Brand  \
# 1         2579          Just Way
# 3         2577           Wei Lih
# 40        2540           Wei Lih
# 65        2515     Uni-President
# 68        2512  Mom's Dry Noodle
# ...        ...               ...
# 2500        80     Unif / Tung-I
# 2512        68           Wei Lih
# 2522        58           Ve Wong
# 2537        43       Kim Ve Wong
# 2572         8            Tung-I
#
#                                                 Variety Style Country Stars  \
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 3                         GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 40        GGE Noodle Snack Wheat Crackers Mexican Spicy  Pack  Taiwan  3.25
# 65      Man Han Feast Spicy Beef Flavor Instant Noodles  Bowl  Taiwan     5
# 68                                       Dan Dan Noodle  Pack  Taiwan     5
# ...                                                 ...   ...     ...   ...
# ...

# %%
# Let#s have a look at the ramen dishes which have rating above than average 
data.loc[data['Stars'] > 2.5]

#TypeError: '>' not supported between instances of 'str' and 'float'
# the colums have type(string)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 # Let#s have a look at the ramen dishes which have rating above than average
# ----> 2 data.loc[data['Stars'] > 2.5]
#
# File c:\Users\a-ara\anaconda3\envs\arab\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\a-ara\anaconda3\envs\arab\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File c:\Users\a-ara\anaconda3\envs\arab\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
# ...

# %%
#find the string without indexing  in list
g =list(filter(lambda x : not str(x).replace('.','',1).isdigit(),data['Stars']))
print(g)
# Out:
# ['Unrated', 'Unrated', 'Unrated']

# %%
# index 
data['Stars'][data['Stars'].apply(lambda x : not str(x).replace('.','',1).isdigit())]
# Out:
# 32     Unrated
# 122    Unrated
# 993    Unrated
# Name: Stars, dtype: object

# %%
try :
    data['Stars'].astype(float)
    data['Stars'] > 2.5
    
except ValueError :
    data['Stars']=data['Stars'].apply(lambda x: float(x) if str(x).replace('.','',1).isdigit() else 0.0) 
data.loc[data['Stars'] > 2.5]
# Out:
#       Review #            Brand  \
# 0         2580        New Touch
# 3         2577          Wei Lih
# 4         2576   Ching's Secret
# 5         2575    Samyang Foods
# 6         2574          Acecook
# ...        ...              ...
# 2564        16          Samyang
# 2566        14          Samyang
# 2567        13  Sapporo Ichiban
# 2572         8           Tung-I
# 2575         5            Vifon
#
#                                                 Variety Style      Country  \
# 0                             T's Restaurant Tantanmen    Cup        Japan
# 3                         GGE Ramen Snack Tomato Flavor  Pack       Taiwan
# 4                                       Singapore Curry  Pack        India
# 5                                Kimchi song Song Ramen  Pack  South Korea
# 6                   Spice Deli Tantan Men With Cilantro   Cup        Japan
# ...                                                 ...   ...          ...
# ...

# %%
data.columns.tolist()
# Out:
# ['Review #', 'Brand', 'Variety', 'Style', 'Country', 'Stars', 'Top Ten']

# %%
# Served dishes in Taiwan with above averge rating 
data.loc[(data['Stars']>2.5) & (data['Country']=='Taiwan')]
# Out:
#       Review #             Brand  \
# 3         2577           Wei Lih
# 40        2540           Wei Lih
# 65        2515     Uni-President
# 68        2512  Mom's Dry Noodle
# 79        2501        Happy Cook
# ...        ...               ...
# 2499        81     Unif / Tung-I
# 2500        80     Unif / Tung-I
# 2512        68           Wei Lih
# 2522        58           Ve Wong
# 2572         8            Tung-I
#
#                                                 Variety Style Country  Stars  \
# 3                         GGE Ramen Snack Tomato Flavor  Pack  Taiwan   2.75
# 40        GGE Noodle Snack Wheat Crackers Mexican Spicy  Pack  Taiwan   3.25
# 65      Man Han Feast Spicy Beef Flavor Instant Noodles  Bowl  Taiwan   5.00
# 68                                       Dan Dan Noodle  Pack  Taiwan   5.00
# 79                                   Toona Paste Noodle  Pack  Taiwan   4.00
# ...                                                 ...   ...     ...    ...
# ...

# %%
# get only the Brand and Style of these dishes 
data.loc[(data['Stars']>2.5) & (data['Country']=='Taiwan'),['Brand','Style']] # condtion columns Stars and Country on columns Brand and styel
# Out:
#                  Brand Style
# 3              Wei Lih  Pack
# 40             Wei Lih  Pack
# 65       Uni-President  Bowl
# 68    Mom's Dry Noodle  Pack
# 79          Happy Cook  Pack
# ...                ...   ...
# 2499     Unif / Tung-I  Pack
# 2500     Unif / Tung-I  Pack
# 2512           Wei Lih  Pack
# 2522           Ve Wong  Pack
# 2572            Tung-I  Pack
#
# [191 rows x 2 columns]

# %%
country_list = data['Country'].unique().tolist()
print(country_list)
# Out:
# ['Japan', 'Taiwan', 'USA', 'India', 'South Korea', 'Singapore', 'Thailand', 'Hong Kong', 'Vietnam', 'Ghana', 'Malaysia', 'Indonesia', 'China', 'Nigeria', 'Germany', 'Hungary', 'Mexico', 'Fiji', 'Australia', 'Pakistan', 'Bangladesh', 'Canada', 'Nepal', 'Brazil', 'UK', 'Myanmar', 'Netherlands', 'United States', 'Cambodia', 'Finland', 'Sarawak', 'Philippines', 'Sweden', 'Colombia', 'Estonia', 'Holland', 'Poland', 'Dubai']

# %%
#have a look at the dishes served in both finland and Sweden 
data.loc[data['Country'].isin(['Finland','Sweden'])]
# Out:
#       Review #   Brand                                Variety Style  Country  \
# 675       1905  Pirkka           Nuudeli Kana Nudlar Kyckling  Pack  Finland
# 816       1764  Pirkka              Nuudeli Tom Yum Katkarapu  Pack  Finland
# 856       1724  Pirkka               Nuudeli Liha Nudlar Kott  Pack  Finland
# 1026      1554     ICA  Asia Fast Noodles Snabbnudlar Räksmak  Pack   Sweden
# 1063      1517   Katoz            Instant Noodles Spicy Chili  Pack   Sweden
# 1093      1487     ICA          Asia Snabbnudlar Kycklingsmak  Pack   Sweden
#
#       Stars Top Ten
# 675    3.50     NaN
# 816    3.75     NaN
# 856    3.50     NaN
# 1026   3.00     NaN
# 1063   3.50     NaN
# 1093   3.25     NaN

# %%
# get the not null values from the top ten 
data.loc[~data['Top Ten'].isnull()]  # ~ 'not' data........isnull() return data['Top Ten'] if not None
# Out:
#       Review #             Brand  \
# 616       1964              MAMA
# 633       1947       Prima Taste
# 655       1925             Prima
# 673       1907       Prima Taste
# 752       1828     Tseng Noodles
# 891       1689      Wugudaochang
# 942       1638  A-Sha Dry Noodle
# 963       1617           MyKuali
# 995       1585            CarJEN
# 1059      1521          Maruchan
# 1072      1508             Mamee
# 1080      1500           MyKuali
# 1109      1471              Mama
# 1114      1466              Mama
# 1230      1350             Mamee
# 1250      1330   Sapporo Ichiban
# 1272      1308          Nongshim
# 1278      1302              Mama
# 1309      1271       Prima Taste
# 1382      1198     Samyang Foods
# 1397      1183             Paldo
# 1493      1087           MyKuali
# 1588       992       Prima Taste
# 1589       991       Prima Taste
# 1646       934          Nongshim
# 1670       910             Paldo
# 1757       823             Paldo
# ...

# %%
data.loc[data['Top Ten'].notnull()]
# Out:
#       Review #             Brand  \
# 616       1964              MAMA
# 633       1947       Prima Taste
# 655       1925             Prima
# 673       1907       Prima Taste
# 752       1828     Tseng Noodles
# 891       1689      Wugudaochang
# 942       1638  A-Sha Dry Noodle
# 963       1617           MyKuali
# 995       1585            CarJEN
# 1059      1521          Maruchan
# 1072      1508             Mamee
# 1080      1500           MyKuali
# 1109      1471              Mama
# 1114      1466              Mama
# 1230      1350             Mamee
# 1250      1330   Sapporo Ichiban
# 1272      1308          Nongshim
# 1278      1302              Mama
# 1309      1271       Prima Taste
# 1382      1198     Samyang Foods
# 1397      1183             Paldo
# 1493      1087           MyKuali
# 1588       992       Prima Taste
# 1589       991       Prima Taste
# 1646       934          Nongshim
# 1670       910             Paldo
# 1757       823             Paldo
# ...

# %% [markdown]
# #Assing Data

# %%
try :
    data['Top Ten']=data['Top Ten'].astype(int)
except ValueError :
      data[['Year','Rank']]=data['Top Ten'] = data['Top Ten'].str.extract(r'(\d{4})\s+#(\d)').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 2
#       1 try :
# ----> 2     data['Top Ten']=data['Top Ten'].astype(int)
#       3 except ValueError :
#
# File c:\Users\a-ara\anaconda3\envs\arab\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#
# File c:\Users\a-ara\anaconda3\envs\arab\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
# ...

# %%
#drop 

# Extract the year and ranking from Top Ten
df =data.loc[data['Top Ten'].notnull()]
df = df.copy()

extracted = df['Top Ten'].str.extract(r'(\d{4})\s+#(\d+)')  #filter [2016#10] \d(4 number) plus 1 \d(1 number) //first and seconf columens



#insert 2 new columens in the DataFrame 
df.loc[:,'Year'] = pd.to_numeric(extracted[0],errors ='coerce').astype('Int64') # str to int //Int suport Nan Value big I but int not
                                 # extracted[0] the first columns (\d{4}) == Year
df.loc[:,'Rank'] = pd.to_numeric(extracted[1],errors='coerce').astype('Int64')
                                 # extracted[1] the second columns (\d+) == Rank  
df.loc[:,'Year'] = df['Year'].ffill().bfill() # return value from last line
df.loc[:,'Rank'] = df['Rank'].fillna(5) # if Ranke =0 return 5 
# df.drop(columns=['Year', 'Rank'], errors='ignore', inplace=True)

df
# Out:
#       Review #             Brand  \
# 616       1964              MAMA
# 633       1947       Prima Taste
# 655       1925             Prima
# 673       1907       Prima Taste
# 752       1828     Tseng Noodles
# 891       1689      Wugudaochang
# 942       1638  A-Sha Dry Noodle
# 963       1617           MyKuali
# 995       1585            CarJEN
# 1059      1521          Maruchan
# 1072      1508             Mamee
# 1080      1500           MyKuali
# 1109      1471              Mama
# 1114      1466              Mama
# 1230      1350             Mamee
# 1250      1330   Sapporo Ichiban
# 1272      1308          Nongshim
# 1278      1302              Mama
# 1309      1271       Prima Taste
# 1382      1198     Samyang Foods
# 1397      1183             Paldo
# 1493      1087           MyKuali
# 1588       992       Prima Taste
# 1589       991       Prima Taste
# 1646       934          Nongshim
# 1670       910             Paldo
# 1757       823             Paldo
# ...

# %%
# Out:
# C:\Users\a-ara\AppData\Local\Temp\ipykernel_9936\1632124070.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<IntegerArray>
# [2016, 2016, 2016, 2016, 2016, 2016, 2015, 2015, 2015, 2015, 2015, 2015, 2013,
#  2015, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2013, 2013, 2013, <NA>,
#  2013, <NA>, 2013, 2012, 2012, 2012, 2012, 2012, <NA>, 2012, 2012, 2012, <NA>,
#  2013, 2012]
# Length: 41, dtype: Int64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:,'Year'] = pd.to_numeric(extracted[0],errors ='coerce').astype('Int64')
# C:\Users\a-ara\AppData\Local\Temp\ipykernel_9936\1632124070.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<IntegerArray>
# [  10,    1,    8,    5,    9,    7,   10,    7,    4,    9,    6,    1,   10,
# ...

# %%
data.loc[data['Top Ten'].notnull()]
# Out:
#       Review #             Brand  \
# 616       1964              MAMA
# 633       1947       Prima Taste
# 655       1925             Prima
# 673       1907       Prima Taste
# 752       1828     Tseng Noodles
# 891       1689      Wugudaochang
# 942       1638  A-Sha Dry Noodle
# 963       1617           MyKuali
# 995       1585            CarJEN
# 1059      1521          Maruchan
# 1072      1508             Mamee
# 1080      1500           MyKuali
# 1109      1471              Mama
# 1114      1466              Mama
# 1230      1350             Mamee
# 1250      1330   Sapporo Ichiban
# 1272      1308          Nongshim
# 1278      1302              Mama
# 1309      1271       Prima Taste
# 1382      1198     Samyang Foods
# 1397      1183             Paldo
# 1493      1087           MyKuali
# 1588       992       Prima Taste
# 1589       991       Prima Taste
# 1646       934          Nongshim
# 1670       910             Paldo
# 1757       823             Paldo
# ...
